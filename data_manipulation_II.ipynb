# %%
SELECT * FROM 'temperatures.csv';
# Out:
#        column0                      date     city        country  avg_temp_c
# 0            0 2000-01-01 00:00:00+00:00  Abidjan  Côte D'Ivoire      27.293
# 1            1 2000-02-01 00:00:00+00:00  Abidjan  Côte D'Ivoire      27.685
# 2            2 2000-03-01 00:00:00+00:00  Abidjan  Côte D'Ivoire      29.061
# 3            3 2000-04-01 00:00:00+00:00  Abidjan  Côte D'Ivoire      28.162
# 4            4 2000-05-01 00:00:00+00:00  Abidjan  Côte D'Ivoire      27.547
# ...        ...                       ...      ...            ...         ...
# 16495    16495 2013-05-01 00:00:00+00:00     Xian          China      18.979
# 16496    16496 2013-06-01 00:00:00+00:00     Xian          China      23.522
# 16497    16497 2013-07-01 00:00:00+00:00     Xian          China      25.251
# 16498    16498 2013-08-01 00:00:00+00:00     Xian          China      24.528
# 16499    16499 2013-09-01 00:00:00+00:00     Xian          China         NaN
#
# [16500 rows x 5 columns]

# %%
import pandas as pd
df = pd.read_csv('temperatures.csv')
df.head()
# Out:
#    Unnamed: 0        date     city        country  avg_temp_c
# 0           0  2000-01-01  Abidjan  Côte D'Ivoire      27.293
# 1           1  2000-02-01  Abidjan  Côte D'Ivoire      27.685
# 2           2  2000-03-01  Abidjan  Côte D'Ivoire      29.061
# 3           3  2000-04-01  Abidjan  Côte D'Ivoire      28.162
# 4           4  2000-05-01  Abidjan  Côte D'Ivoire      27.547

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16500 entries, 0 to 16499
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  16500 non-null  int64
#  1   date        16500 non-null  object
#  2   city        16500 non-null  object
#  3   country     16500 non-null  object
#  4   avg_temp_c  16407 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 644.7+ KB

# %%
# Drop column name is Unnamed: 0
df = df.drop(columns='Unnamed: 0')

# %%
# Set the index of temperatures to city
temperatures_ind = df.set_index('city')
print(temperatures_ind)
# Out:
#                date        country  avg_temp_c
# city
# Abidjan  2000-01-01  Côte D'Ivoire      27.293
# Abidjan  2000-02-01  Côte D'Ivoire      27.685
# Abidjan  2000-03-01  Côte D'Ivoire      29.061
# Abidjan  2000-04-01  Côte D'Ivoire      28.162
# Abidjan  2000-05-01  Côte D'Ivoire      27.547
# ...             ...            ...         ...
# Xian     2013-05-01          China      18.979
# Xian     2013-06-01          China      23.522
# Xian     2013-07-01          China      25.251
# Xian     2013-08-01          China      24.528
# Xian     2013-09-01          China         NaN
#
# [16500 rows x 3 columns]

# %%
#Subsetting on index values for Paris
temperatures_ind.loc["Paris"]
# Out:
#              date country  avg_temp_c
# city
# Paris  2000-01-01  France       3.845
# Paris  2000-02-01  France       6.587
# Paris  2000-03-01  France       7.872
# Paris  2000-04-01  France      10.067
# Paris  2000-05-01  France      15.451
# ...           ...     ...         ...
# Paris  2013-05-01  France      11.703
# Paris  2013-06-01  France      16.340
# Paris  2013-07-01  France      21.186
# Paris  2013-08-01  France      19.235
# Paris  2013-09-01  France         NaN
#
# [165 rows x 3 columns]

# %%
# Reset the temperatures_ind index, keeping its contents
print(temperatures_ind.reset_index())
# Out:
#           city        date        country  avg_temp_c
# 0      Abidjan  2000-01-01  Côte D'Ivoire      27.293
# 1      Abidjan  2000-02-01  Côte D'Ivoire      27.685
# 2      Abidjan  2000-03-01  Côte D'Ivoire      29.061
# 3      Abidjan  2000-04-01  Côte D'Ivoire      28.162
# 4      Abidjan  2000-05-01  Côte D'Ivoire      27.547
# ...        ...         ...            ...         ...
# 16495     Xian  2013-05-01          China      18.979
# 16496     Xian  2013-06-01          China      23.522
# 16497     Xian  2013-07-01          China      25.251
# 16498     Xian  2013-08-01          China      24.528
# 16499     Xian  2013-09-01          China         NaN
#
# [16500 rows x 4 columns]

# %%
# Reset the temperatures_ind index, droping its contents
print(temperatures_ind.reset_index(drop=True))
# Out:
#              date        country  avg_temp_c
# 0      2000-01-01  Côte D'Ivoire      27.293
# 1      2000-02-01  Côte D'Ivoire      27.685
# 2      2000-03-01  Côte D'Ivoire      29.061
# 3      2000-04-01  Côte D'Ivoire      28.162
# 4      2000-05-01  Côte D'Ivoire      27.547
# ...           ...            ...         ...
# 16495  2013-05-01          China      18.979
# 16496  2013-06-01          China      23.522
# 16497  2013-07-01          China      25.251
# 16498  2013-08-01          China      24.528
# 16499  2013-09-01          China         NaN
#
# [16500 rows x 3 columns]

# %% [markdown]
# # Subsetting with .loc[ ]

# %%
# Make a list of cities to subset on
cities = ["Moscow", "Saint Petersburg"]

# Subset temperatures using square brackets
print(df[df['city'].isin(cities)])
# Out:
#              date              city country  avg_temp_c
# 10725  2000-01-01            Moscow  Russia      -7.313
# 10726  2000-02-01            Moscow  Russia      -3.551
# 10727  2000-03-01            Moscow  Russia      -1.661
# 10728  2000-04-01            Moscow  Russia      10.096
# 10729  2000-05-01            Moscow  Russia      10.357
# ...           ...               ...     ...         ...
# 13360  2013-05-01  Saint Petersburg  Russia      12.355
# 13361  2013-06-01  Saint Petersburg  Russia      17.185
# 13362  2013-07-01  Saint Petersburg  Russia      17.234
# 13363  2013-08-01  Saint Petersburg  Russia      17.153
# 13364  2013-09-01  Saint Petersburg  Russia         NaN
#
# [330 rows x 4 columns]

# %%
# Subset temperatures_ind using .loc[]
print(temperatures_ind.loc[cities])
# Out:
#                         date country  avg_temp_c
# city
# Moscow            2000-01-01  Russia      -7.313
# Moscow            2000-02-01  Russia      -3.551
# Moscow            2000-03-01  Russia      -1.661
# Moscow            2000-04-01  Russia      10.096
# Moscow            2000-05-01  Russia      10.357
# ...                      ...     ...         ...
# Saint Petersburg  2013-05-01  Russia      12.355
# Saint Petersburg  2013-06-01  Russia      17.185
# Saint Petersburg  2013-07-01  Russia      17.234
# Saint Petersburg  2013-08-01  Russia      17.153
# Saint Petersburg  2013-09-01  Russia         NaN
#
# [330 rows x 3 columns]

# %% [markdown]
# # Setting multi-level indexes

# %%
# Index temperatures by country & city
temperatures_ind = df.set_index(['country','city'])

# %%
print(type(temperatures_ind))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# List of tuples: France, Paris & Germany, Berlin
rows_to_keep = [("France","Paris"),("Germany","Berlin")]

# Subset for rows to keep
print(temperatures_ind.loc[rows_to_keep])
# Out:
#                       date  avg_temp_c
# country city
# France  Paris   2000-01-01       3.845
#         Paris   2000-02-01       6.587
#         Paris   2000-03-01       7.872
#         Paris   2000-04-01      10.067
#         Paris   2000-05-01      15.451
# ...                    ...         ...
# Germany Berlin  2013-05-01      14.139
#         Berlin  2013-06-01      17.473
#         Berlin  2013-07-01      20.901
#         Berlin  2013-08-01      19.335
#         Berlin  2013-09-01         NaN
#
# [330 rows x 2 columns]

# %%
# Sort temperatures_ind by index values
print(temperatures_ind.sort_index())
# Out:
#                           date  avg_temp_c
# country     city
# Afghanistan Kabul   2000-01-01       3.326
#             Kabul   2000-02-01       3.454
#             Kabul   2000-03-01       9.612
#             Kabul   2000-04-01      17.925
#             Kabul   2000-05-01      24.658
# ...                        ...         ...
# Zimbabwe    Harare  2013-05-01      18.298
#             Harare  2013-06-01      17.020
#             Harare  2013-07-01      16.299
#             Harare  2013-08-01      19.232
#             Harare  2013-09-01         NaN
#
# [16500 rows x 2 columns]

# %%
# Sort temperatures_ind by index values at the city level
print(temperatures_ind.sort_index(level='city'))
# Out:
#                              date  avg_temp_c
# country       city
# Côte D'Ivoire Abidjan  2000-01-01      27.293
#               Abidjan  2000-02-01      27.685
#               Abidjan  2000-03-01      29.061
#               Abidjan  2000-04-01      28.162
#               Abidjan  2000-05-01      27.547
# ...                           ...         ...
# China         Xian     2013-05-01      18.979
#               Xian     2013-06-01      23.522
#               Xian     2013-07-01      25.251
#               Xian     2013-08-01      24.528
#               Xian     2013-09-01         NaN
#
# [16500 rows x 2 columns]

# %%
# Sort temperatures_ind by country then descending city
print(temperatures_ind.sort_index(level=['country','city'], ascending=[True, False]))
# Out:
#                           date  avg_temp_c
# country     city
# Afghanistan Kabul   2000-01-01       3.326
#             Kabul   2000-02-01       3.454
#             Kabul   2000-03-01       9.612
#             Kabul   2000-04-01      17.925
#             Kabul   2000-05-01      24.658
# ...                        ...         ...
# Zimbabwe    Harare  2013-05-01      18.298
#             Harare  2013-06-01      17.020
#             Harare  2013-07-01      16.299
#             Harare  2013-08-01      19.232
#             Harare  2013-09-01         NaN
#
# [16500 rows x 2 columns]

# %% [markdown]
# # Slicing index values

# %%
# Sort the index of temperatures_ind
temperatures_srt = temperatures_ind.sort_index()

# %%
# Subset rows from Pakistan to Russia
print(temperatures_srt.loc['Pakistan':'Russia'])
# Out:
#                                  date  avg_temp_c
# country  city
# Pakistan Faisalabad        2000-01-01      12.792
#          Faisalabad        2000-02-01      14.339
#          Faisalabad        2000-03-01      20.309
#          Faisalabad        2000-04-01      29.072
#          Faisalabad        2000-05-01      34.845
# ...                               ...         ...
# Russia   Saint Petersburg  2013-05-01      12.355
#          Saint Petersburg  2013-06-01      17.185
#          Saint Petersburg  2013-07-01      17.234
#          Saint Petersburg  2013-08-01      17.153
#          Saint Petersburg  2013-09-01         NaN
#
# [1155 rows x 2 columns]

# %%
# Try to subset rows from Athens to Moscow
print(temperatures_srt.loc['Ahmadabad':'Moskow'])
# Out:
#                           date  avg_temp_c
# country city
# Angola  Luanda      2000-01-01      25.077
#         Luanda      2000-02-01      25.493
#         Luanda      2000-03-01      26.496
#         Luanda      2000-04-01      25.689
#         Luanda      2000-05-01      25.113
# ...                        ...         ...
# Morocco Casablanca  2013-05-01      19.217
#         Casablanca  2013-06-01      23.649
#         Casablanca  2013-07-01      27.488
#         Casablanca  2013-08-01      27.952
#         Casablanca  2013-09-01         NaN
#
# [10725 rows x 2 columns]

# %%
# Subset rows from India, Ahmadabad to Iraq, Baghdad
print(temperatures_srt.loc[('India','Ahmadabad'):('Iraq','Baghdad')])
# Out:
#                          date  avg_temp_c
# country city
# India   Ahmadabad  2000-01-01      20.781
#         Ahmadabad  2000-02-01      21.246
#         Ahmadabad  2000-03-01      26.565
#         Ahmadabad  2000-04-01      32.275
#         Ahmadabad  2000-05-01      32.847
# ...                       ...         ...
# Iraq    Baghdad    2013-05-01      28.673
#         Baghdad    2013-06-01      33.803
#         Baghdad    2013-07-01      36.392
#         Baghdad    2013-08-01      35.463
#         Baghdad    2013-09-01         NaN
#
# [2970 rows x 2 columns]

# %%
# Subset columns from date to avg_temp_c
print(temperatures_srt.loc[:,'date':'avg_temp_c'])
# Out:
#                           date  avg_temp_c
# country     city
# Afghanistan Kabul   2000-01-01       3.326
#             Kabul   2000-02-01       3.454
#             Kabul   2000-03-01       9.612
#             Kabul   2000-04-01      17.925
#             Kabul   2000-05-01      24.658
# ...                        ...         ...
# Zimbabwe    Harare  2013-05-01      18.298
#             Harare  2013-06-01      17.020
#             Harare  2013-07-01      16.299
#             Harare  2013-08-01      19.232
#             Harare  2013-09-01         NaN
#
# [16500 rows x 2 columns]

# %%
# Subset in both directions at once
print(temperatures_srt.loc[('India','Hyderabad'):('Iraq','Baghdad'),'date':'avg_temp_c'])
# Out:
#                          date  avg_temp_c
# country city
# India   Hyderabad  2000-01-01      23.779
#         Hyderabad  2000-02-01      25.826
#         Hyderabad  2000-03-01      28.821
#         Hyderabad  2000-04-01      32.698
#         Hyderabad  2000-05-01      32.438
# ...                       ...         ...
# Iraq    Baghdad    2013-05-01      28.673
#         Baghdad    2013-06-01      33.803
#         Baghdad    2013-07-01      36.392
#         Baghdad    2013-08-01      35.463
#         Baghdad    2013-09-01         NaN
#
# [2145 rows x 2 columns]
